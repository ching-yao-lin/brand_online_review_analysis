# %%
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
from bs4 import BeautifulSoup
import requests

class ForumPost:
    
    # CLASS VARIABLE
    num_of_post = 0
    
    def __init__(self, title, content, date, replies):
        self.title = title
        self.content = content
        self.date = date
        self.replies = replies
        
        ForumPost.num_of_post += 1
    
    @property
    def data(self):
        return self.title, self.content, self.date, self.replies
    
    def __repr__(self):
        return f'ForumPost({self.title}, {self.content}, {self.date}, {self.replies})'

def get_forum_content(tid):
    
    "Webscrape the title, content, date, and replies of a post for a given topic_id(tid)"
    
    all_replies = []
    
    page_no = 1
    while True:
        # Get the webpage
        try:
            html = requests.get(f'https://fgforum.fashionguide.com.tw/post_list?topic_id={tid}&page={page_no}')
        except HTTPError as e:
            # couldn't find the webpage on the server
            print(e)
        except URLError as e:
            # More severe problem: cannot find the server
            print('The server could not be found!')
        except Exception as e:
            # Other unknown problems
            print('Sorry, something went wrong...')
            print(e)
        else:
            # Test if no exception are thrown
            print('Webpage successfully retrieved!')

        # Create a BeautifulSoup Object from the webpage
        soup = BeautifulSoup(html.text, 'lxml')

        # Scrape the post title
        try:
            title = soup.find_all('h1', {'class': 'forum-topic-title'})[0].text
        except IndexError as e:
            print("There's no title! title is set to ''.")
            title = ''
            print(e)

        # Scrape the post content
        try:
            content = soup.find_all('div', {'class': 'forum-topic-body'})[0].text
        except IndexError as e:
            print("There's no content! content is set to ''.")
            content = ''
            print(e)

        # Scrape the post date
        try:
            date = soup.find_all('div', {'class': 'forum-post-date'})[0].text
        except IndexError as e:
            print("There's no date! date is set to ''.")
            date = ''
            print(e)

        # Scrape the comments
        replies = []
        for reply in soup.find_all('div', {'class': 'forum-reply-body'}):
            replies.append(reply.text.strip())

        # break if there's no replies, which means we have reached the end of the comments
        if not replies:
            print('Reached the end of the comments!')
            break
        
        # join the replies in the page together, and append them to all_replies
        all_replies.append('\n'.join(replies))

        # Check for the next page!
        page_no += 1

    title = title.strip()
    content = content.strip()
    date = date.strip()
    # join all_replies from different pages together
    replies = '\n'.join(all_replies).strip()
    
#     print('TITLE: ', title)
#     print('CONTENT: ', content)
#     print('DATE: ', date)
#     print('REPLIES: \n', replies)
    
    return title, content, date, replies

def get_ForumPosts(brand_tids):
    """
    Scrape the posts for the given brand topic_ids (brand_tids);
    Create ForumPost objects out of them.
    Returns a list of ForumPost objects
    """
    all_fps = []
    for tid in brand_tids:
        title, content, date, replies = get_forum_content(tid)
        fp = ForumPost(title, content, date, replies)
#         print(fp)
        all_fps.append(fp)
    
    return all_fps

def write2file(filename, brand_ForumPosts):
    import csv
    
    with open(filename + '.csv', 'w', errors='ignore') as new_file:
        # Create a csv.writer object from the new_file
        csv_writer = csv.writer(new_file)
        
        # Write the headers
        csv_writer.writerow(['title', 'content', 'date', 'replies'])
        
        # Write the data
        for fp in brand_ForumPosts:
            csv_writer.writerow(list(fp.data))
        
def main():
    
    MaxAndCo_tids = [50451, 83452, 50599, 65458, 144859, 85500, 139272, 117781, 75798, 47918, 74335, 114806, 28284, 2468, 80250, 120932, 32609, 32588, 58190,\
                    108197, 139194, 114804, 92295, 23108, 40358, 76971, 81728, 41680, 117960, 127702, 123300, 481927, 96654, 36099, 420911, 21404, 29098, 11168,\
                    106080, 134912, 896740, 92205, 57287, 2933, 18886, 91376, 8895, 135305, 8380, 135400, 56128, 74314, 28461, 106720, 42471, 11678, 36877,\
                    5284, 7648, 10536, 130778, 679538, 820706, 65619, 416378, 727098, 75003, 18169, 5626, 15961, 16599, 797504]
    
    ClubMonaco_tids = [134791, 113152, 154713, 774413, 108923, 75459, 121743, 105345, 4887, 43687, 107667, 137493, 91395, 26903, 119449, 116873,\
                       125320, 121089, 379448, 1234789, 771513, 5961]

    Joseph_tids = [234830, 38860, 907714, 10391, 908181, 552904, 25377, 136768, 89732, 36286, 247163, 97175, 90999, 821929, 126807, 32295, 653512,\
                   1163260, 805535, 786710, 779239, 179785, 724221, 549700, 122569, 6600, 8154918, 537039, 38278, 167683]
    
    Maje_tids = [48868, 132450, 906434, 1290942, 118052, 905954, 906114, 119983, 93570, 912921, 907072, 108113, 137998]
    
    iCB_tids = [113152, 1, 5, 99335, 51723, 123411, 79380, 532, 83480, 272920, 21021, 100896, 123961, 86074, 34365, 136768, 891458, 296008, 116812,\
                54357, 72314, 97916, 1335939, 958603, 1012883, 86164, 108694, 108187, 121501, 1269405, 22688, 108197, 115888, 100529, 9399, 3255,\
                1269947, 120514, 122569, 85194, 66281, 98045, 43280, 134934, 5917, 289, 675106, 27938, 29487, 132404, 57144, 75067, 135484, 4413,\
                24381, 10559, 37196, 122708, 86361, 1223515, 116578, 4451, 116580, 110442, 81265, 128369, 2933, 113017, 113039, 55190, 67481, 81314,\
                9642, 119220, 25533, 332739, 105427, 20437, 968666, 144859, 957405, 57313, 91113, 53737, 74739, 83955, 127995, 905726]
    
    ToryBurch_tids = [992671, 1323220, 1234122, 989951, 802555, 1021073, 134170, 398639, 1020248, 1167424, 145598, 1005428, 83713, 3, 169,\
                      594, 5958, 303, 362]
    
    # Create a list of ForumPost objects
    MaxAndCo_ForumPosts = get_ForumPosts(MaxAndCo_tids)
    ClubMonaco_ForumPosts = get_ForumPosts(ClubMonaco_tids)
    Joseph_ForumPosts = get_ForumPosts(Joseph_tids)
    Maje_ForumPosts = get_ForumPosts(Maje_tids)
    iCB_ForumPosts = get_ForumPosts(iCB_tids)
    ToryBurch_ForumPosts = get_ForumPosts(ToryBurch_tids)
    
    # Write to a new csv file using filename='MAx&Co'
    write2file('Max&Co', MaxAndCo_ForumPosts)
    write2file('ClubMonaco', ClubMonaco_ForumPosts)
    write2file('Joseph', Joseph_ForumPosts)
    write2file('Maje', Maje_ForumPosts)
    write2file('iCB', iCB_ForumPosts)
    write2file('ToryBurch', ToryBurch_ForumPosts)
    
if __name__ == '__main__':
    main()
# Out:
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range
# Webpage successfully retrieved!
# There's no title! title is set to ''.
# list index out of range
# There's no content! content is set to ''.
# list index out of range
# There's no date! date is set to ''.
# list index out of range

# %%
# Tests

# %%
# from urllib.request import urlopen
# from urllib.error import HTTPError, URLError
# from bs4 import BeautifulSoup
# import requests

# %%
# 反"防爬蟲"
# session = requests.Session()
# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36",
#     "referer": "https://search.fashionguide.com.tw/?q=Max&Co",
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
#     "Cookie": "_ga=GA1.3.573203763.1586706102; _gid=GA1.3.1325547597.1586706102; __auc=bdcc8b5a1716f0db642022d6da6; __gads=ID=a2a4b57264378a21:T=1586706102:S=ALNI_MYHxuYtpoWp4H6hh-D-NtCZ0ddoDQ; _fbp=fb.2.1586706103512.200015964; __cfduid=dc94827c7c43f6d566c76c65afdb0116c1586707318; __asc=16cbb8d01716f6cde003bf9c5eb; fgt=13dea5b95a534c6a845f9b13d10381e0",
#     "Accept'Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7"
# }

# try:
#     req = urlopen('https://fgblog.fashionguide.com.tw/content/2279192')
# except HTTPError as e:
#     # couldn't find the webpage on the server
#     print(e)
# except URLError as e:
#     # More severe problem: cannot find the server
#     print('The server could not be found!')
# else:
#     # Test if no exception are thrown
#     print('It worked!')

# bs = BeautifulSoup(req)
# print(bs.prettify())
# Out:
# It worked!
# <!DOCTYPE html>
# <html class="no-js" lang="zh-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    MAX&amp;Co. 2016春夏女裝系列 - FashionGuide 華人時尚專業評鑑
#   </title>
#   <link href="https://fgblog.fashionguide.com.tw/content/2279192" rel="canonical"/>
#   <meta content="zh_TW" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="MAX&amp;Co. 2016春夏女裝系列 - FashionGuide 華人時尚專業評鑑" property="og:title"/>
#   <meta content="MAX&amp;Co. 2016春夏女裝系列 與MAX&amp;Co.品牌大使奧莉薇亞‧巴勒莫 (Oliv …" property="og:description"/>
#   <meta content="https://fgblog.fashionguide.com.tw/content/2279192" property="og:url"/>
#   <meta content="FashionGuide 華人時尚專業評鑑" property="og:site_name"/>
#   <meta content="https://www.facebook.com/FashionGuide.com.tw" property="article:publisher"/>
#   <meta content="MAX&amp;Co." property="article:tag"/>
#   <meta content="PPF原則" property="article:tag"/>
#   <meta content="春裝" property="article:tag"/>
#   <meta content="穿搭" property="article:tag"/>
#   <meta content="重複搭配" property="article:tag"/>
#   <meta content="FG新聞中心" property="article:section"/>
#   <meta content="2016-02-24T05:21:00+00:00" property="article:published_time"/>
#   <meta content="1590515954569893" property="fb:app_id"/>
#   <meta content="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/85f968c5-9597-4b78-a471-ab5a30e09e3b.png" property="og:image"/>
#   <meta content="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/85f968c5-9597-4b78-a471-ab5a30e09e3b.png" property="og:image:secure_url"/>
#   <meta content="600" property="og:image:width"/>
#   <meta content="600" property="og:image:height"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="MAX&amp;Co. 2016春夏女裝系列 與MAX&amp;Co.品牌大使奧莉薇亞‧巴勒莫 (Oliv […]" name="twitter:description"/>
#   <meta content="MAX&amp;Co. 2016春夏女裝系列 - FashionGuide 華人時尚專業評鑑" name="twitter:title"/>
#   <meta content="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/85f968c5-9597-4b78-a471-ab5a30e09e3b.png" name="twitter:image"/>
#   <meta content="wordpress-plugin" name="pwaforwp"/>
#   <meta content="#ff8a82" name="theme-color"/>
#   <link href="/content/pwa-manifest.json" rel="manifest"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/pwa-for-wp/images/logo.png" rel="apple-touch-icon" sizes="192x192"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/pwa-for-wp/images/logo-512x512.png" rel="apple-touch-icon" sizes="512x512"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/2279192/amp" rel="amphtml"/>
#   <meta content="AMP for WP 0.9.97.62" name="generator"/>
#   <link href="//s0.wp.com" rel="dns-prefetch"/>
#   <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
#   <link href="//stackpath.bootstrapcdn.com" rel="dns-prefetch"/>
#   <link href="//cdn.rawgit.com" rel="dns-prefetch"/>
#   <link href="//use.fontawesome.com" rel="dns-prefetch"/>
#   <script data-cfasync="false" type="text/javascript">
#    var mi_version='7.10.0';var mi_track_user=true;var mi_no_track_reason='';var disableStr='ga-disable-UA-27192993-1';function __gaTrackerIsOptedOut(){return document.cookie.indexOf(disableStr+'=true')>-1;}
# if(__gaTrackerIsOptedOut()){window[disableStr]=true;}
# function __gaTrackerOptout(){document.cookie=disableStr+'=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';window[disableStr]=true;}
# if(mi_track_user){(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');__gaTracker('create','UA-27192993-1','auto');__gaTracker('set','forceSSL',true);__gaTracker('require','displayfeatures');__gaTracker('send','pageview');}else{console.log("");(function(){var noopfn=function(){return null;};var noopnullfn=function(){return null;};var Tracker=function(){return null;};var p=Tracker.prototype;p.get=noopfn;p.set=noopfn;p.send=noopfn;var __gaTracker=function(){var len=arguments.length;if(len===0){return;}
# var f=arguments[len-1];if(typeof f!=='object'||f===null||typeof f.hitCallback!=='function'){console.log('Not running function __gaTracker('+arguments[0]+" ....) because you are not being tracked. "+mi_no_track_reason);return;}
# try{f.hitCallback();}catch(ex){}};__gaTracker.create=function(){return new Tracker();};__gaTracker.getByName=noopnullfn;__gaTracker.getAll=function(){return[];};__gaTracker.remove=noopfn;window['__gaTracker']=__gaTracker;})();}
#   </script>
#   <style type="text/css">
#    img.wp-smiley,img.emoji{display:inline!important;border:none!important;box-shadow:none!important;height:1em!important;width:1em!important;margin:0 .07em!important;vertical-align:-.1em!important;background:none!important;padding:0!important}
#   </style>
#   <link href="https://c0.wp.com/c/5.2.5/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/foobox-image-lightbox/free/css/foobox.free.min.css?ver=2.7.3" id="foobox-free-min-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/pwa-for-wp/assets/css/pwaforwp-main.min.css?ver=1.2" id="pwaforwp-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.css?ver=1.9.0" id="slick-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick-theme.min.css?ver=1.9.0" id="slick-theme-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/css/bootstrap.min.css?ver=4.1.1" id="bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://use.fontawesome.com/releases/v5.1.0/css/all.css?ver=5.1.0" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/fancybox/3.3.5/jquery.fancybox.min.css?ver=3.3.5" id="fancybox-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.rawgit.com/michalsnik/aos/2.1.1/dist/aos.css?ver=2.1.1" id="aos-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/themes/innovext/dist/css/main.min.css?ver=1537248881" id="theme-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/p/jetpack/7.5.4/css/jetpack.css" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://c0.wp.com/c/5.2.5/wp-includes/js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <script src="https://c0.wp.com/c/5.2.5/wp-includes/js/jquery/jquery-migrate.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# var related_posts_js_options={"post_heading":"h4"};
# //]]>
#   </script>
#   <script src="https://c0.wp.com/p/jetpack/7.5.4/_inc/build/related-posts/related-posts.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# var monsterinsights_frontend={"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[]","home_url":"https:\/\/fgblog.fashionguide.com.tw\/content","hash_tracking":"false"};
# //]]>
#   </script>
#   <script src="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend.min.js?ver=7.10.0" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var FOOBOX=window.FOOBOX={ready:true,preloadFont:true,disableOthers:false,o:{wordpress:{enabled:true},countMessage:'image %index of %total',excludes:'.fbx-link,.nofoobox,.nolightbox,a[href*="pinterest.com/pin/create/button/"]',affiliate:{enabled:false}},selectors:[".foogallery-container.foogallery-lightbox-foobox",".foogallery-container.foogallery-lightbox-foobox-free",".gallery",".wp-block-gallery",".wp-caption",".wp-block-image","a:has(img[class*=wp-image-])",".foobox"],pre:function($){},post:function($){},custom:function($){}};
#   </script>
#   <script src="https://fgblog.fashionguide.com.tw/content/wp-content/plugins/foobox-image-lightbox/free/js/foobox.free.min.js?ver=2.7.3" type="text/javascript">
#   </script>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <link href="https://fgblog.fashionguide.com.tw/content/?p=33339" rel="shortlink"/>
#   <meta content="1590515954569893" property="fb:app_id"/>
#   <script type="application/ld+json">
#    {"@context":"http:\/\/schema.org\/","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https:\/\/fgblog.fashionguide.com.tw\/content\/2279192"},"url":"https:\/\/fgblog.fashionguide.com.tw\/content\/2279192","headline":"MAX&Co....","datePublished":"2016-02-24T13:21:00+08:00","dateModified":"2016-02-24T13:21:00+00:00","publisher":{"@type":"Organization","@id":"https:\/\/fgblog.fashionguide.com.tw\/content#organization","name":"FashionGuide","logo":{"@type":"ImageObject","url":"https:\/\/front-wordpress.fashionguide.com.tw\/wp-content\/uploads\/2018\/08\/logo.png","width":600,"height":60}},"image":{"@type":"ImageObject","url":"https:\/\/front-wordpress.fashionguide.com.tw\/wp-content\/uploads\/2018\/08\/85f968c5-9597-4b78-a471-ab5a30e09e3b.png","width":696,"height":600},"articleSection":"FG新聞中心","description":"MAX&Co. 2016春夏女裝系列 與MAX&Co.品牌大使奧莉薇亞‧巴勒莫 (Olivia P","author":{"@type":"Person","name":"FG編輯","url":"https:\/\/fgblog.fashionguide.com.tw\/content\/author\/fg-editor","image":{"@type":"ImageObject","url":"https:\/\/secure.gravatar.com\/avatar\/39465bb28d40a14910b43901128e24e4?s=96&d=mm&r=g","height":96,"width":96}},"commentCount":"0"}
#   </script>
#   <link href="//c0.wp.com" rel="dns-prefetch"/>
#   <style type="text/css">
#    img#wpstats{display:none}
#   </style>
#   <script type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "item": {
#                 "@id": "https://fgblog.fashionguide.com.tw/content",
#                 "name": "Home"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "item": {
#                 "@id": "https://fgblog.fashionguide.com.tw/content/2279192",
#                 "name": "MAX&#038;Co. 2016\u6625\u590f\u5973\u88dd\u7cfb\u5217",
#                 "image": "https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/85f968c5-9597-4b78-a471-ab5a30e09e3b.png"
#             }
#         }
#     ]
# }
#   </script>
#   <link href="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/logo.png" rel="icon" sizes="32x32"/>
#   <link href="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/logo.png" rel="icon" sizes="192x192"/>
#   <link href="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/logo.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/logo.png" name="msapplication-TileImage"/>
#   <style id="wp-custom-css" type="text/css">
#    .article-paper h2{font-size:1.5rem;margin-top:2rem;margin-bottom:1.5rem}.post-date{display:none}.article-paper .entry-meta .article-author .author-name span.author{color:#000}.article-paper .entry-meta .article-author .author-name span{display:block;text-decoration:none;color:inherit;font-family:"Microsoft JhengHei","\5FAE\8EDF\6B63\9ED1\9AD4",sans-serif;font-size:14px;background-color:transparent;padding:0;margin:0;color:#757575}#categories-3,#nav_menu-2{display:none}.article-paper .share-links-icon ul li.share-facebook a{padding:0 2px;margin-right:5px}.article-paper .share-links-icon ul li.share-line a{padding:0 2px}.article-paper .entry-author{margin:50px 0 0 0}.share-links-icon,.related{margin-bottom:10px}.header-info ul{display:inline-flex}.header-wrapper .nav-top .header-info ul li{display:flex;padding:0 10px}.header-wrapper .nav-top .header-info ul li.search svg{align-self:center}.header-wrapper .nav-top .header-info ul li.social-icons a{margin-right:2px}.header-wrapper .nav-top .header-info a{display:inline-flex}.header-wrapper .nav-top .header-info a span{align-self:center}.header-wrapper .nav-top .header-info a span{top:0}.article-paper .entry-author .author-bio h2{margin-top:0}.article-paper .entry-author img{margin-left:0;width:100%}#custom_html-2{display:none}@media (min-width:768px){.article-paper .entry-author .author-bio{margin-left:0;padding-right:0}}.article-footer{margin-top:0}#recent-posts-3{border-bottom:0}#recent-posts-3 ul{margin-bottom:0}#recent-posts-3 ul li{border-bottom:0}.facebook-comment{margin-bottom:50px}.article-paper .tag span{line-height:1}.article-paper .tag a{margin-left:0;margin-right:10px}.article-content .aligncenter,.article-content div.aligncenter{display:table}
#   </style>
#   <noscript>
#    <style id="rocket-lazyload-nojs-css">
#     .rll-youtube-player,[data-lazy-src]{display:none!important}
#    </style>
#   </noscript>
#   <link href="https://fgblog.fashionguide.com.tw/content/wp-content/themes/innovext/images/favicon.png" rel="shortcut icon"/>
#   <script async="async" src="https://www.google.com/adsense/search/ads.js">
#   </script>
#   <script charset="utf-8" type="text/javascript">
#    (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
#   </script>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-WJFF7F5');
#   </script>
#  </head>
#  <body class="post-template-default single single-post postid-33339 single-format-standard">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WJFF7F5" style="display: none;" width="0">
#    </iframe>
#   </noscript>
#   <header>
#    <div class="header-wrapper">
#     <div class="nav-top">
#      <div class="container">
#       <div class="row no-margin">
#        <div class="col-7 col-lg-4 logo no-padding">
#         <a href="https://www.fashionguide.com.tw/">
#          <svg viewbox="0 0 239 43.28" xmlns="http://www.w3.org/2000/svg">
#           <g>
#            <polygon class="cls-1" points="60.95 7.28 60.95 4.62 50.46 4.62 50.46 23.38 53.3 23.38 53.3 14.45 60.73 14.45 60.73 11.79 53.3 11.79 53.3 7.28 60.95 7.28">
#            <path class="cls-1" d="M37.13,8.36a21.56,21.56,0,0,0-14.47,5.55H37.14v4.3H25.75v7.52h8.81a11.57,11.57,0,0,1,8.35-3.58,11.72,11.72,0,0,1,10.91,7.53l.16.41H49.23L49.14,30a7.41,7.41,0,0,0-6.23-3.43,7.66,7.66,0,0,0,0,15.31,7.43,7.43,0,0,0,6.76-4.39h-5V33.2h10v.28c0,.25,0,.48,0,.7a11.77,11.77,0,1,1-23.53,0A12.16,12.16,0,0,1,31.89,30H25.75V41.34H21.23v-26a21.63,21.63,0,1,0,15.9-7Z" transform="translate(-15.49 -8.36)">
#            </path>
#           </g>
#          </svg>
#         </a>
#        </div>
#        <div class="col-5 header-info d-block text-right d-md-block d-lg-none no-padding">
#         <a href="https://lunar.fashionguide.com.tw/login?return_url=https://www.fashionguide.com.tw/" target="_blank">
#          <svg aria-hidden="true" class="svg-inline--fa fa-user-circle fa-w-16" data-fa-i2svg="" data-icon="user-circle" data-prefix="fas" role="img" viewbox="0 0 496 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M248 8C111 8 0 119 0 256s111 248 248 248 248-111 248-248S385 8 248 8zm0 96c48.6 0 88 39.4 88 88s-39.4 88-88 88-88-39.4-88-88 39.4-88 88-88zm0 344c-58.7 0-111.3-26.6-146.5-68.2 18.8-35.4 55.6-59.8 98.5-59.8 2.4 0 4.8.4 7.1 1.1 13 4.2 26.6 6.9 40.9 6.9 14.3 0 28-2.7 40.9-6.9 2.3-.7 4.7-1.1 7.1-1.1 42.9 0 79.7 24.4 98.5 59.8C359.3 421.4 306.7 448 248 448z" fill="currentColor">
#           </path>
#          </svg>
#         </a>
#         <a class="btn-search-open" href='href="javascript:;"'>
#          <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor">
#           </path>
#          </svg>
#         </a>
#         <a class="menu-toggle" href='href="javascript:;"'>
#          <svg aria-hidden="true" class="svg-inline--fa fa-bars fa-w-14" data-fa-i2svg="" data-icon="bars" data-prefix="fas" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M16 132h416c8.837 0 16-7.163 16-16V76c0-8.837-7.163-16-16-16H16C7.163 60 0 67.163 0 76v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16z" fill="currentColor">
#           </path>
#          </svg>
#         </a>
#        </div>
#        <div class="col-lg-5 offset-lg-3 text-right d-none d-md-none d-lg-block no-padding">
#         <div class="header-info">
#          <ul>
#           <li class="user-info">
#            <a class="account-center" href="https://lunar.fashionguide.com.tw/login?return_url=https://www.fashionguide.com.tw/" target="_blank">
#             <svg aria-hidden="true" class="svg-inline--fa fa-user-circle fa-w-16" data-fa-i2svg="" data-icon="user-circle" data-prefix="fas" role="img" viewbox="0 0 496 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M248 8C111 8 0 119 0 256s111 248 248 248 248-111 248-248S385 8 248 8zm0 96c48.6 0 88 39.4 88 88s-39.4 88-88 88-88-39.4-88-88 39.4-88 88-88zm0 344c-58.7 0-111.3-26.6-146.5-68.2 18.8-35.4 55.6-59.8 98.5-59.8 2.4 0 4.8.4 7.1 1.1 13 4.2 26.6 6.9 40.9 6.9 14.3 0 28-2.7 40.9-6.9 2.3-.7 4.7-1.1 7.1-1.1 42.9 0 79.7 24.4 98.5 59.8C359.3 421.4 306.7 448 248 448z" fill="currentColor">
#              </path>
#             </svg>
#             <span>
#              登入 / 註冊
#             </span>
#            </a>
#           </li>
#           <li class="search">
#            <a class="btn-search-open" href='href="javascript:;"'>
#             <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor">
#              </path>
#             </svg>
#            </a>
#           </li>
#           <li class="social-icons">
#            <a href="https://www.facebook.com/FashionGuide.com.tw" target="blank">
#             <svg aria-hidden="true" class="svg-inline--fa fa-facebook-square fa-w-14" data-fa-i2svg="" data-icon="facebook-square" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M448 80v352c0 26.5-21.5 48-48 48h-85.3V302.8h60.6l8.7-67.6h-69.3V192c0-19.6 5.4-32.9 33.5-32.9H384V98.7c-6.2-.8-27.4-2.7-52.2-2.7-51.6 0-87 31.5-87 89.4v49.9H184v67.6h60.9V480H48c-26.5 0-48-21.5-48-48V80c0-26.5 21.5-48 48-48h352c26.5 0 48 21.5 48 48z" fill="currentColor">
#              </path>
#             </svg>
#            </a>
#            <a href="https://www.instagram.com/fashionguidecorp/" target="blank">
#             <svg aria-hidden="true" class="svg-inline--fa fa-instagram fa-w-14" data-fa-i2svg="" data-icon="instagram" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M224.1 141c-63.6 0-114.9 51.3-114.9 114.9s51.3 114.9 114.9 114.9S339 319.5 339 255.9 287.7 141 224.1 141zm0 189.6c-41.1 0-74.7-33.5-74.7-74.7s33.5-74.7 74.7-74.7 74.7 33.5 74.7 74.7-33.6 74.7-74.7 74.7zm146.4-194.3c0 14.9-12 26.8-26.8 26.8-14.9 0-26.8-12-26.8-26.8s12-26.8 26.8-26.8 26.8 12 26.8 26.8zm76.1 27.2c-1.7-35.9-9.9-67.7-36.2-93.9-26.2-26.2-58-34.4-93.9-36.2-37-2.1-147.9-2.1-184.9 0-35.8 1.7-67.6 9.9-93.9 36.1s-34.4 58-36.2 93.9c-2.1 37-2.1 147.9 0 184.9 1.7 35.9 9.9 67.7 36.2 93.9s58 34.4 93.9 36.2c37 2.1 147.9 2.1 184.9 0 35.9-1.7 67.7-9.9 93.9-36.2 26.2-26.2 34.4-58 36.2-93.9 2.1-37 2.1-147.8 0-184.8zM398.8 388c-7.8 19.6-22.9 34.7-42.6 42.6-29.5 11.7-99.5 9-132.1 9s-102.7 2.6-132.1-9c-19.6-7.8-34.7-22.9-42.6-42.6-11.7-29.5-9-99.5-9-132.1s-2.6-102.7 9-132.1c7.8-19.6 22.9-34.7 42.6-42.6 29.5-11.7 99.5-9 132.1-9s102.7-2.6 132.1 9c19.6 7.8 34.7 22.9 42.6 42.6 11.7 29.5 9 99.5 9 132.1s2.7 102.7-9 132.1z" fill="currentColor">
#              </path>
#             </svg>
#            </a>
#            <a href="https://www.youtube.com/user/fashionguide" target="blank">
#             <svg aria-hidden="true" class="svg-inline--fa fa-youtube-square fa-w-14" data-fa-i2svg="" data-icon="youtube-square" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M186.8 202.1l95.2 54.1-95.2 54.1V202.1zM448 80v352c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V80c0-26.5 21.5-48 48-48h352c26.5 0 48 21.5 48 48zm-42 176.3s0-59.6-7.6-88.2c-4.2-15.8-16.5-28.2-32.2-32.4C337.9 128 224 128 224 128s-113.9 0-142.2 7.7c-15.7 4.2-28 16.6-32.2 32.4-7.6 28.5-7.6 88.2-7.6 88.2s0 59.6 7.6 88.2c4.2 15.8 16.5 27.7 32.2 31.9C110.1 384 224 384 224 384s113.9 0 142.2-7.7c15.7-4.2 28-16.1 32.2-31.9 7.6-28.5 7.6-88.1 7.6-88.1z" fill="currentColor">
#              </path>
#             </svg>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="search-form-wrapper" style="display:none;">
#      <form action="/" class="search-form" id="search-form" method="get" role="search">
#       <div class="search-input-group">
#        <input class="search-field" name="s" placeholder="請輸入關鍵字" type="search" value=""/>
#        <button class="search-submit" type="submit">
#         <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#          <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor">
#          </path>
#         </svg>
#        </button>
#       </div>
#      </form>
#      <button class="arrow-btn btn-search-collape">
#       <svg aria-hidden="true" class="svg-inline--fa fa-angle-up fa-w-10" data-fa-i2svg="" data-icon="angle-up" data-prefix="fas" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#        <path d="M177 159.7l136 136c9.4 9.4 9.4 24.6 0 33.9l-22.6 22.6c-9.4 9.4-24.6 9.4-33.9 0L160 255.9l-96.4 96.4c-9.4 9.4-24.6 9.4-33.9 0L7 329.7c-9.4-9.4-9.4-24.6 0-33.9l136-136c9.4-9.5 24.6-9.5 34-.1z" fill="currentColor">
#        </path>
#       </svg>
#      </button>
#     </div>
#     <div class="nav-bottom">
#      <div class="desktop d-none d-md-none d-lg-block">
#       <div class="container">
#        <nav class="desktop-menu">
#         <div class="menu-main-menu-container">
#          <ul class="menu d-flex justify-content-between" id="menu-main-menu">
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-has-children menu-item-40574" id="menu-item-40574">
#            <a href="https://fgblog.fashionguide.com.tw/content/">
#             FG報報
#            </a>
#            <ul class="sub-menu">
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40575" id="menu-item-40575">
#              <a href="https://fgblog.fashionguide.com.tw/content/makeup">
#               彩妝
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40576" id="menu-item-40576">
#              <a href="https://fgblog.fashionguide.com.tw/content/skincare">
#               保養
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40577" id="menu-item-40577">
#              <a href="https://fgblog.fashionguide.com.tw/content/fashion">
#               時尚
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40578" id="menu-item-40578">
#              <a href="https://fgblog.fashionguide.com.tw/content/lifestyle">
#               好好生活
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40579" id="menu-item-40579">
#              <a href="https://fgblog.fashionguide.com.tw/content/news">
#               最新消息
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-49262" id="menu-item-49262">
#              <a href="https://fgblog.fashionguide.com.tw/content/beauty-trial">
#               FG試用台
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-73022" id="menu-item-73022">
#              <a href="https://fgblog.fashionguide.com.tw/content/lifestyle/disney">
#               迪士尼迷
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-61479" id="menu-item-61479">
#            <a href="https://survey.fashionguide.com.tw/academy-register/2">
#             評鑑學院
#            </a>
#            <ul class="sub-menu">
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-61480" id="menu-item-61480">
#              <a href="https://survey.fashionguide.com.tw/academy-register/2">
#               第二期
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-61481" id="menu-item-61481">
#              <a href="https://survey.fashionguide.com.tw/academy-register/1">
#               第一期
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-69322" id="menu-item-69322">
#            <a href="https://survey.fashionguide.com.tw/flight-attendant">
#             空姐評鑑
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9" id="menu-item-9">
#            <a href="https://survey.fashionguide.com.tw/expert">
#             專家認證
#            </a>
#            <ul class="sub-menu">
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38161" id="menu-item-38161">
#              <a href="https://survey.fashionguide.com.tw/expert">
#               專家認證商品
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-44903" id="menu-item-44903">
#              <a href="https://survey.fashionguide.com.tw/expert_intro">
#               專家評審團介紹
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38163" id="menu-item-38163">
#              <a href="https://www.fashionguide.com.tw/activity/award/202003">
#               美妝榜
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-40570" id="menu-item-40570">
#            <a href="https://survey.fashionguide.com.tw/">
#             特優評鑑
#            </a>
#            <ul class="sub-menu">
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40571" id="menu-item-40571">
#              <a href="https://survey.fashionguide.com.tw/">
#               特優評鑑商品
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40572" id="menu-item-40572">
#              <a href="https://www.fashionguide.com.tw/activity/award/202003">
#               美妝榜
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-48282" id="menu-item-48282">
#              <a href="https://survey.fashionguide.com.tw/evaluation/member/intro">
#               專業評鑑員
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38172" id="menu-item-38172">
#              <a href="https://fgblog.fashionguide.com.tw/category/9/last_posts">
#               時尚穿搭
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38175" id="menu-item-38175">
#              <a href="https://fgblog.fashionguide.com.tw/category/12/last_posts">
#               休閒興趣
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38168" id="menu-item-38168">
#              <a href="https://fgblog.fashionguide.com.tw/category/11/last_posts">
#               生活心情
#              </a>
#             </li>
#             <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38171" id="menu-item-38171">
#              <a href="https://fgblog.fashionguide.com.tw/category/13/last_posts">
#               星座兩性
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </div>
#     <div class="d-block d-md-block d-lg-none">
#      <div class="mobile-menu-container">
#       <div class="close-toggle-container">
#        <span class="close-toggle">
#         <svg height="100%" viewbox="0 0 35.413 35.413" width="100%" xmlns="http://www.w3.org/2000/svg">
#          <path d="M20.535 17.294L34.002 3.827c.781-.781.781-2.047 0-2.828-.78-.781-2.048-.781-2.828 0L17.707 14.466 4.242.999c-.78-.781-2.047-.781-2.828 0s-.781 2.047 0 2.828l13.465 13.467L.586 31.587c-.781.781-.781 2.047 0 2.828.39.391.902.586 1.414.586s1.024-.195 1.414-.586l14.293-14.293L32 34.415c.391.391.902.586 1.414.586s1.023-.195 1.414-.586c.781-.781.781-2.047 0-2.828L20.535 17.294z">
#          </path>
#         </svg>
#        </span>
#       </div>
#       <nav class="mobile-menu">
#        <ul class="menu" id="menu-main-menu-1">
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-has-children menu-item-40574">
#          <a href="https://fgblog.fashionguide.com.tw/content/">
#           FG報報
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40575">
#            <a href="https://fgblog.fashionguide.com.tw/content/makeup">
#             彩妝
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40576">
#            <a href="https://fgblog.fashionguide.com.tw/content/skincare">
#             保養
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40577">
#            <a href="https://fgblog.fashionguide.com.tw/content/fashion">
#             時尚
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40578">
#            <a href="https://fgblog.fashionguide.com.tw/content/lifestyle">
#             好好生活
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-40579">
#            <a href="https://fgblog.fashionguide.com.tw/content/news">
#             最新消息
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-49262">
#            <a href="https://fgblog.fashionguide.com.tw/content/beauty-trial">
#             FG試用台
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-73022">
# ...
#          </a>
#          <span class="post-date">
#           2020-04-28
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/funsiamo-momscake-200428">
#           為她親手製作的滿滿心意！Funsiamo母親節「芋泥季」蛋糕，用濃郁芋頭香氣擄獲媽媽的心
#          </a>
#          <span class="post-date">
#           2020-04-28
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/wanpo-brands-200428">
#           「我喝的不是手搖，是健康！」萬波 x 白蘭氏跨界聯名推出補氣飲品，直接加一整罐養蔘飲超霸氣！
#          </a>
#          <span class="post-date">
#           2020-04-28
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/animal-crossing-200427">
#           聽老歌、看老影集、玩動物森友會，疫情生活壓力讓我們變得更「懷舊」！
#          </a>
#          <span class="post-date">
#           2020-04-27
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/nars-laguna-200427">
#           經典修容色#LAGUNA換上如陽光親吻般的金燦光澤！NARS全新「性感小金盤」展現迷人魅力
#          </a>
#          <span class="post-date">
#           2020-04-27
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/lux-shampoo-200427">
#           打破LUX傳統印象！全新「髮の補給機能飲系列」文青風包裝、洗完後柔順蓬鬆感都令人驚艷！
#          </a>
#          <span class="post-date">
#           2020-04-27
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/icemonster-ice-200427">
#           不用擔心飲料融化變淡！ICE MONSTER全新「茶冰塊」越喝越濃厚！首推珍珠厚奶茶、霸氣葡萄水果茶
#          </a>
#          <span class="post-date">
#           2020-04-27
#          </span>
#         </li>
#         <li>
#          <a href="https://fgblog.fashionguide.com.tw/content/givenchy-hubertedtion-200427">
#           誘惑黑色蕾絲圍繞瓶身，紀梵希2020訂製蕾絲限量系列，三大經典產品換上絕美新裝
#          </a>
#          <span class="post-date">
#           2020-04-27
#          </span>
#         </li>
#        </ul>
#       </section>
#       <section class="widget_text widget widget_custom_html" id="custom_html-2">
#        <div class="textwidget custom-html-widget">
#         <div id="afscontainer1">
#         </div>
#         <script charset="utf-8" type="text/javascript">
#          var pageOptions={"pubId":"pub-9616389000213823","query":"hotels","adPage":1};var adblock1={"container":"afscontainer1","width":"700","number":2};_googCsa('ads',pageOptions,adblock1);
#         </script>
#        </div>
#       </section>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="article-footer">
#    <div class="container">
#     <div class="row no-margin">
#      <div class="col-12 col-md-6 no-padding article-footer-border">
#       <div class="further-reading">
#        <a href="https://fgblog.fashionguide.com.tw/content/227917" rel="prev">
#         <div class="post-thumbnail">
#          <img alt="" class="attachment-square-thumbnails size-square-thumbnails wp-post-image" height="400" src="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/56deb304-1f24-4fe7-9484-242ff74a497f-400x400.png" width="400"/>
#         </div>
#         <span class="nav-meta">
#          上一篇文章
#         </span>
#         <span class="nav-title">
#          【電影】《錦衣衛-繡春刀》劉詩詩又愛又恨張震 戲裡情路坎坷 古裝扮相再驚艷
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="col-12 col-md-6 no-padding over-hidden">
#       <div class="further-reading">
#        <a href="https://fgblog.fashionguide.com.tw/content/227920" rel="prev">
#         <div class="post-thumbnail">
#          <img alt="" class="attachment-square-thumbnails size-square-thumbnails wp-post-image" height="400" src="https://front-wordpress.fashionguide.com.tw/wp-content/uploads/2018/08/9aff54d1-9b50-48f5-b68d-4b8ee6ce8cae-400x400.png" width="400"/>
#         </div>
#         <span class="nav-meta">
#          下一篇文章
#         </span>
#         <span class="nav-title">
#          EVE LOM 開啓早春淨白，推出「全能潤白系列」新品
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <foot
#         <path class="cls-2" d="M180.65,16.91V33.08H178.2V16.91Z" transform="translate(-8.9 -8.81)">
#         </path>
#         <path class="cls-2" d="M184.53,33.08V16.91h3.39a12.45,12.45,0,0,1,3.86.48A7.2,7.2,0,0,1,194.53,19a7.72,7.72,0,0,1,2.5,6,7.64,7.64,0,0,1-2.61,6,7.51,7.51,0,0,1-2.74,1.6,12.47,12.47,0,0,1-3.8.45ZM187,30.79h1.1a9.1,9.1,0,0,0,2.73-.35,5.4,5.4,0,0,0,2-1.16,5.53,5.53,0,0,0,1.8-4.28,5.62,5.62,0,0,0-1.78-4.32,6.76,6.76,0,0,0-4.72-1.47H187Z" transform="translate(-8.9 -8.81)">
#         </path>
#         <path class="cls-2" d="M209,19.21h-6.48v3.88h6.3v2.29h-6.3v5.41H209v2.29H200.1V16.91H209Z" transform="translate(-8.9 -8.81)">
#         </path>
#         <path class="cls-1" d="M25,8.81A16.09,16.09,0,0,0,14.24,13H25v3.21H16.55v5.6h6.56a8.63,8.63,0,0,1,6.23-2.67,8.75,8.75,0,0,1,8.14,5.62l.12.3H34.05l-.07-.1a5.52,5.52,0,0,0-4.64-2.56,5.71,5.71,0,0,0,0,11.42,5.53,5.53,0,0,0,5-3.27H30.62V27.33h7.46v.21a4.79,4.79,0,0,1,0,.52,8.77,8.77,0,1,1-17.54,0A9,9,0,0,1,21.12,25H16.55V33.4H13.18V14A16.13,16.13,0,1,0,25,8.81Z" transform="translate(-8.9 -8.81)">
#         </path>
#        </svg>
#        <span>
#         華人時尚專業評鑑
#        </span>
#       </a>
#      </div>
#      <div class="social-icons">
#       <a href="https://www.facebook.com/FashionGuide.com.tw" target="blank">
#        <svg aria-hidden="true" class="svg-inline--fa fa-facebook-square fa-w-14" data-fa-i2svg="" data-icon="facebook-square" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#         <path d="M448 80v352c0 26.5-21.5 48-48 48h-85.3V302.8h60.6l8.7-67.6h-69.3V192c0-19.6 5.4-32.9 33.5-32.9H384V98.7c-6.2-.8-27.4-2.7-52.2-2.7-51.6 0-87 31.5-87 89.4v49.9H184v67.6h60.9V480H48c-26.5 0-48-21.5-48-48V80c0-26.5 21.5-48 48-48h352c26.5 0 48 21.5 48 48z" fill="currentColor">
#         </path>
#        </svg>
#       </a>
#       <a href="https://www.instagram.com/fashionguidecorp/" target="blank">
#        <svg aria-hidden="true" class="svg-inline--fa fa-instagram fa-w-14" data-fa-i2svg="" data-icon="instagram" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#         <path d="M224.1 141c-63.6 0-114.9 51.3-114.9 114.9s51.3 114.9 114.9 114.9S339 319.5 339 255.9 287.7 141 224.1 141zm0 189.6c-41.1 0-74.7-33.5-74.7-74.7s33.5-74.7 74.7-74.7 74.7 33.5 74.7 74.7-33.6 74.7-74.7 74.7zm146.4-194.3c0 14.9-12 26.8-26.8 26.8-14.9 0-26.8-12-26.8-26.8s12-26.8 26.8-26.8 26.8 12 26.8 26.8zm76.1 27.2c-1.7-35.9-9.9-67.7-36.2-93.9-26.2-26.2-58-34.4-93.9-36.2-37-2.1-147.9-2.1-184.9 0-35.8 1.7-67.6 9.9-93.9 36.1s-34.4 58-36.2 93.9c-2.1 37-2.1 147.9 0 184.9 1.7 35.9 9.9 67.7 36.2 93.9s58 34.4 93.9 36.2c37 2.1 147.9 2.1 184.9 0 35.9-1.7 67.7-9.9 93.9-36.2 26.2-26.2 34.4-58 36.2-93.9 2.1-37 2.1-147.8 0-184.8zM398.8 388c-7.8 19.6-22.9 34.7-42.6 42.6-29.5 11.7-99.5 9-132.1 9s-102.7 2.6-132.1-9c-19.6-7.8-34.7-22.9-42.6-42.6-11.7-29.5-9-99.5-9-132.1s-2.6-102.7 9-132.1c7.8-19.6 22.9-34.7 42.6-42.6 29.5-11.7 99.5-9 132.1-9s102.7-2.6 132.1 9c19.6 7.8 34.7 22.9 42.6 42.6 11.7 29.5 9 99.5 9 132.1s2.7 102.7-9 132.1z" fill="currentColor">
#         </path>
#        </svg>
#       </a>
#       <a href="https://www.youtube.com/user/fashionguide" target="blank">
#        <svg aria-hidden="true" class="svg-inline--fa fa-youtube-square fa-w-14" data-fa-i2svg="" data-icon="youtube-square" data-prefix="fab" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#         <path d="M186.8 202.1l95.2 54.1-95.2 54.1V202.1zM448 80v352c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V80c0-26.5 21.5-48 48-48h352c26.5 0 48 21.5 48 48zm-42 176.3s0-59.6-7.6-88.2c-4.2-15.8-16.5-28.2-32.2-32.4C337.9 128 224 128 224 128s-113.9 0-142.2 7.7c-15.7 4.2-28 16.6-32.2 32.4-7.6 28.5-7.6 88.2-7.6 88.2s0 59.6 7.6 88.2c4.2 15.8 16.5 27.7 32.2 31.9C110.1 384 224 384 224 384s113.9 0 142.2-7.7c15.7-4.2 28-16.1 32.2-31.9 7.6-28.5 7.6-88.1 7.6-88.1z" fill="currentColor">
#         </path>
#        </svg>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="footer-main text-center">
#     <div class="container">
#      <div class="menu-footer-menu-container">
#       <ul class="menu" id="menu-footer-menu">
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-30" id="menu-item-30">
#         <a href="https://www.fashionguide.com.tw/about">
#          關於 FG
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-31" id="menu-item-31">
#         <a href="https://www.fashionguide.com.tw/channel/award/index.html">
#          美妝大賞
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-32" id="menu-item-32">
#         <a href="https://form.jotform.me/81821902305450">
#          服務台
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-33" id="menu-item-33">
#         <a href="https://lunar.fashionguide.com.tw/login">
#          修改會員資料
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-34" id="menu-item-34">
#         <a href="https://member.fashionguide.com.tw/account/?cmd=add">
#          加入會員
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-35" id="menu-item-35">
#         <a href="http://www.fashionguide.com.tw/Forum/bbs_help.htm">
#          新手上路
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-36" id="menu-item-36">
#         <a href="http://buy.fashionguide.com.tw/">
#          品牌評鑑
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-37" id="menu-item-37">
#         <a href="https://forum.fashionguide.com.tw/act_rule.php">
#          贈獎須知
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-38" id="menu-item-38">
#         <a href="http://www.fashionguide.com.tw/rule.asp">
#          服務條款
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-39" id="menu-item-39">
#         <a href="http://www.104.com.tw/jobbank/cust_job/introduce.cfm?j=503a44273c463f675a583a1d1d1d1d5f2443a363189j48&amp;jobsource=checkc">
#          人才招募
#         </a>
#        </li>
#       </ul>
#      </div>
#      <p>
#       風尚數位科技股份有限公司版權所有
#       <span>
#        FashionGuide All Rights Reserved
#       </span>
#      </p>
#     </div>
#    </div>
#   </footer>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(d.getElementById(id))return;js=d.createElement(s);js.id=id;js.src="//connect.facebook.net/zh_TW/sdk.js#xfbml=1&appId=1590515954569893&version=v2.3";fjs.parentNode.insertBefore(js,fjs);}(document,'script','facebook-jssdk'));
#   </script>
#   <link href="https://c0.wp.com/c/5.2.5/wp-includes/css/dashicons.min.css" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/c/5.2.5/wp-includes/js/thickbox/thickbox.css" id="thickbox-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=202018" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.matchHeight/0.7.2/jquery.matchHeight-min.js?ver=0.7.2" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/fancybox/3.3.5/jquery.fancybox.min.js?ver=3.3.5" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.js?ver=1.9.0" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.0/umd/popper.min.js?ver=1.14.0" type="text/javascript">
#   </script>
#   <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.0/js/bootstrap.min.js?ver=4.1.0" type="text/javascript">
#   </script>
#   <script src="https://cdn.rawgit.com/michalsnik/aos/2.1.1/dist/aos.js?ver=2.1.1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# var Inno_Object={"ajax_url":"https:\/\/fgblog.fashionguide.com.tw\/content\/wp-admin\/admin-ajax.php","posts_per_page":"10"};
# //]]>
#   </script>
#   <script src="https://fgblog.fashionguide.com.tw/content/wp-content/themes/innovext/dist/js/app.min.js?ver=1537248881" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# var thickboxL10n={"next":"\u4e0b\u4e00\u5f35 >","prev":"< \u4e0a\u4e00\u5f35","image":"\u5716\u7247","of":"\/","close":"\u95dc\u9589","noiframes":"\u9019\u9805\u529f\u80fd\u9700\u8981 iframe \u624d\u80fd\u9054\u6210\u3002\u4f60\u505c\u7528\u4e86\u76ee\u524d\u4f7f\u7528\u7684\u700f\u89bd\u5668\u7684 iframe \u529f\u80fd\u6216\u76ee\u524d\u4f7f\u7528\u7684\u700f\u89bd\u5668\u4e0d\u652f\u63f4 iframe \u529f\u80fd\u3002","loadingAnimation":"https:\/\/fgblog.fashionguide.com.tw\/content\/wp-includes\/js\/thickbox\/loadingAnimation.gif"};
# //]]>
#   </script>
#   <script src="https://c0.wp.com/c/5.2.5/wp-includes/js/thickbox/thickbox.js" type="text/javascript">
#   </script>
#   <script src="https://fgblog.fashionguide.com.tw/content/pwa-register-sw.js">
#   </script>
#   <script async="async" defer="defer" src="https://stats.wp.com/e-202018.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    _stq=window._stq||[];_stq.push(['view',{v:'ext',j:'1:7.5.4',blog:'163829224',post:'33339',tz:'8',srv:'fgblog.fashionguide.com.tw'}]);_stq.push(['clickTrackerInit','163829224','33339']);
#   </script>
#  </body>
# </html>
# <!-- This website is like a Rocket, isn't it? Performance optimized by WP Rocket. Learn more: https://wp-rocket.me -->
